# %% [markdown]
# ### **Mounting the google drive to the colab environment:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Assessment_Final_Data'
# Out:
# /content/drive/MyDrive/Assessment_Final_Data

# %% [markdown]
# # TASK 1: DATA HANDLING

# %% [markdown]
# ## LOADING THE DATASET

# %%
# %ls
# Out:
# combined_output.csv
# PRSA_Data_Dingling_20130301-20170228.csv
# PRSA_Data_Shunyi_20130301-20170228.csv
# PRSA_Data_Tiantan_20130301-20170228.csv
# PRSA_Data_Wanliu_20130301-20170228.csv
# PRSA_Data_Wanshouxigong_20130301-20170228.csv

# %%
import pandas as pd
import glob

# Get all CSV files in the folder
csv_files = glob.glob("/content/drive/MyDrive/Assessment_Final_Data/*.csv")
csv_files
# Out:
# ['/content/drive/MyDrive/Assessment_Final_Data/PRSA_Data_Dingling_20130301-20170228.csv',
#  '/content/drive/MyDrive/Assessment_Final_Data/PRSA_Data_Wanshouxigong_20130301-20170228.csv',
#  '/content/drive/MyDrive/Assessment_Final_Data/PRSA_Data_Tiantan_20130301-20170228.csv',
#  '/content/drive/MyDrive/Assessment_Final_Data/PRSA_Data_Shunyi_20130301-20170228.csv',
#  '/content/drive/MyDrive/Assessment_Final_Data/PRSA_Data_Wanliu_20130301-20170228.csv',
#  '/content/drive/MyDrive/Assessment_Final_Data/combined_output.csv']

# %% [markdown]
# ## COMBINING ALL THE DATASETS TO ONE DATAFRAME

# %%
# Read and combine all CSV files
combined_df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)
combined_df
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0  3.0   NaN  200.0  82.0
# 1           2  2013      3    1     1    7.0   7.0  3.0   NaN  200.0  80.0
# 2           3  2013      3    1     2    5.0   5.0  3.0   2.0  200.0  79.0
# 3           4  2013      3    1     3    6.0   6.0  3.0   NaN  200.0  79.0
# 4           5  2013      3    1     4    5.0   5.0  3.0   NaN  200.0  81.0
# ...       ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 701275  35060  2017      2   28    19   11.0  32.0  3.0  24.0  400.0  72.0
# 701276  35061  2017      2   28    20   13.0  32.0  3.0  41.0  500.0  50.0
# 701277  35062  2017      2   28    21   14.0  28.0  4.0  38.0  500.0  54.0
# 701278  35063  2017      2   28    22   12.0  23.0  4.0  30.0  400.0  59.0
# 701279  35064  2017      2   28    23   13.0  19.0  4.0  38.0  600.0  49.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# 0       -2.3  1020.8 -19.7   0.0    E   0.5       Dingling
# 1       -2.5  1021.3 -19.0   0.0  ENE   0.7       Dingling
# 2       -3.0  1021.3 -19.9   0.0  ENE   0.2       Dingling
# 3       -3.6  1021.8 -19.1   0.0  NNE   1.0       Dingling
# 4       -3.5  1022.3 -19.4   0.0    N   2.1       Dingling
# ...      ...     ...   ...   ...  ...   ...            ...
# 701275  12.5  1013.5 -16.2   0.0   NW   2.4  Wanshouxigong
# 701276  11.6  1013.6 -15.1   0.0  WNW   0.9  Wanshouxigong
# 701277  10.8  1014.2 -13.3   0.0   NW   1.1  Wanshouxigong
# 701278  10.5  1014.4 -12.9   0.0  NNW   1.2  Wanshouxigong
# 701279   8.6  1014.1 -15.9   0.0  NNE   1.3  Wanshouxigong
#
# [701280 rows x 18 columns]

# %%
df1 = combined_df.drop_duplicates()
df1
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0  3.0   NaN  200.0  82.0
# 1           2  2013      3    1     1    7.0   7.0  3.0   NaN  200.0  80.0
# 2           3  2013      3    1     2    5.0   5.0  3.0   2.0  200.0  79.0
# 3           4  2013      3    1     3    6.0   6.0  3.0   NaN  200.0  79.0
# 4           5  2013      3    1     4    5.0   5.0  3.0   NaN  200.0  81.0
# ...       ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 175315  35060  2017      2   28    19   11.0  27.0  4.0  20.0  300.0  81.0
# 175316  35061  2017      2   28    20   15.0  43.0  6.0  55.0  500.0  45.0
# 175317  35062  2017      2   28    21   13.0  35.0  7.0  48.0  500.0  48.0
# 175318  35063  2017      2   28    22   12.0  31.0  5.0  47.0  500.0  50.0
# 175319  35064  2017      2   28    23    7.0  25.0  6.0  86.0  700.0  11.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# 0       -2.3  1020.8 -19.7   0.0    E   0.5  Dingling
# 1       -2.5  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2       -3.0  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3       -3.6  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4       -3.5  1022.3 -19.4   0.0    N   2.1  Dingling
# ...      ...     ...   ...   ...  ...   ...       ...
# 175315  12.6  1011.9 -14.3   0.0    N   2.0    Wanliu
# 175316   9.4  1012.3 -11.9   0.0  WSW   1.0    Wanliu
# 175317   8.7  1012.8 -13.7   0.0    N   1.1    Wanliu
# 175318   7.8  1012.9 -12.6   0.0  NNE   1.0    Wanliu
# 175319   7.0  1012.6 -11.2   0.0   NE   1.1    Wanliu
#
# [175320 rows x 18 columns]

# %%
# Save to a new CSV file
df1.to_csv("combined_output.csv", index=False)

print("All CSV files have been merged into 'combined_output.csv'.")
# Out:
# All CSV files have been merged into 'combined_output.csv'.

# %% [markdown]
# # TASK2 : EDA(EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# ## A) FUNDAMENTAL DATA UNDERSTANDING

# %%
df1.shape
# Out:
# (175320, 18)

# %%
df1.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2',
#        'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175320 entries, 0 to 175319
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       175320 non-null  int64
#  1   year     175320 non-null  int64
#  2   month    175320 non-null  int64
#  3   day      175320 non-null  int64
#  4   hour     175320 non-null  int64
#  5   PM2.5    171873 non-null  float64
#  6   PM10     172751 non-null  float64
#  7   SO2      170932 non-null  float64
#  8   NO2      170153 non-null  float64
#  9   CO       166895 non-null  float64
#  10  O3       168589 non-null  float64
#  11  TEMP     175157 non-null  float64
#  12  PRES     175160 non-null  float64
#  13  DEWP     175154 non-null  float64
#  14  RAIN     175159 non-null  float64
#  15  wd       174417 non-null  object
#  16  WSPM     175192 non-null  float64
#  17  station  175320 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 25.4+ MB

# %%
selected_columns = ['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2','CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station']
df = df1[selected_columns]
df
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0  3.0   NaN  200.0  82.0
# 1           2  2013      3    1     1    7.0   7.0  3.0   NaN  200.0  80.0
# 2           3  2013      3    1     2    5.0   5.0  3.0   2.0  200.0  79.0
# 3           4  2013      3    1     3    6.0   6.0  3.0   NaN  200.0  79.0
# 4           5  2013      3    1     4    5.0   5.0  3.0   NaN  200.0  81.0
# ...       ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 175315  35060  2017      2   28    19   11.0  27.0  4.0  20.0  300.0  81.0
# 175316  35061  2017      2   28    20   15.0  43.0  6.0  55.0  500.0  45.0
# 175317  35062  2017      2   28    21   13.0  35.0  7.0  48.0  500.0  48.0
# 175318  35063  2017      2   28    22   12.0  31.0  5.0  47.0  500.0  50.0
# 175319  35064  2017      2   28    23    7.0  25.0  6.0  86.0  700.0  11.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# 0       -2.3  1020.8 -19.7   0.0    E   0.5  Dingling
# 1       -2.5  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2       -3.0  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3       -3.6  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4       -3.5  1022.3 -19.4   0.0    N   2.1  Dingling
# ...      ...     ...   ...   ...  ...   ...       ...
# 175315  12.6  1011.9 -14.3   0.0    N   2.0    Wanliu
# 175316   9.4  1012.3 -11.9   0.0  WSW   1.0    Wanliu
# 175317   8.7  1012.8 -13.7   0.0    N   1.1    Wanliu
# 175318   7.8  1012.9 -12.6   0.0  NNE   1.0    Wanliu
# 175319   7.0  1012.6 -11.2   0.0   NE   1.1    Wanliu
#
# [175320 rows x 18 columns]

# %%
# Missing values
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()

        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)

        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        print(mis_val_table)

        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})

        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns.sort_values(
        '% of Total Values', ascending=False)

        # Return the dataframe with missing information
        return mis_val_table_ren_columns

missing_values= missing_values_table(df)
missing_values.style.background_gradient(cmap='RdYlGn_r')
# Out:
#             0         1
# No          0  0.000000
# year        0  0.000000
# month       0  0.000000
# day         0  0.000000
# hour        0  0.000000
# PM2.5    3447  1.966119
# PM10     2569  1.465321
# SO2      4388  2.502852
# NO2      5167  2.947182
# CO       8425  4.805499
# O3       6731  3.839265
# TEMP      163  0.092973
# PRES      160  0.091262
# DEWP      166  0.094684
# RAIN      161  0.091832
# wd        903  0.515058
# WSPM      128  0.073009
# station     0  0.000000
# <style type="text/css">
# #T_cb73f_row0_col0, #T_cb73f_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_cb73f_row1_col0, #T_cb73f_row1_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_cb73f_row2_col0, #T_cb73f_row2_col1 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_cb73f_row3_col0, #T_cb73f_row3_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_cb73f_row4_col0, #T_cb73f_row4_col1 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_cb73f_row5_col0, #T_cb73f_row5_col1 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_cb73f_row6_col0, #T_cb73f_row6_col1 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_cb73f_row7_col0, #T_cb73f_row7_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_cb73f_row8_col0, #T_cb73f_row8_col1, #T_cb73f_row9_col0, #T_cb73f_row9_col1, #T_cb73f_row10_col0, #T_cb73f_row10_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_cb73f_row11_col0, #T_cb73f_row11_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_cb73f_row12_col0, #T_cb73f_row12_col1, #T_cb73f_row13_col0, #T_cb73f_row13_col1, #T_cb73f_row14_col0, #T_cb73f_row14_col1, #T_cb73f_row15_col0, #T_cb73f_row15_col1, #T_cb73f_row16_col0, #T_cb73f_row16_col1, #T_cb73f_row17_col0, #T_cb73f_row17_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb73f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb73f_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_cb73f_level0_col1" class="col_heading level0 col1" >% of Total Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb73f_level0_row0" class="row_heading level0 row0" >CO</th>
#       <td id="T_cb73f_row0_col0" class="data row0 col0" >8425</td>
#       <td id="T_cb73f_row0_col1" class="data row0 col1" >4.805499</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row1" class="row_heading level0 row1" >O3</th>
#       <td id="T_cb73f_row1_col0" class="data row1 col0" >6731</td>
#       <td id="T_cb73f_row1_col1" class="data row1 col1" >3.839265</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row2" class="row_heading level0 row2" >NO2</th>
#       <td id="T_cb73f_row2_col0" class="data row2 col0" >5167</td>
#       <td id="T_cb73f_row2_col1" class="data row2 col1" >2.947182</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row3" class="row_heading level0 row3" >SO2</th>
#       <td id="T_cb73f_row3_col0" class="data row3 col0" >4388</td>
#       <td id="T_cb73f_row3_col1" class="data row3 col1" >2.502852</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row4" class="row_heading level0 row4" >PM2.5</th>
#       <td id="T_cb73f_row4_col0" class="data row4 col0" >3447</td>
#       <td id="T_cb73f_row4_col1" class="data row4 col1" >1.966119</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row5" class="row_heading level0 row5" >PM10</th>
#       <td id="T_cb73f_row5_col0" class="data row5 col0" >2569</td>
#       <td id="T_cb73f_row5_col1" class="data row5 col1" >1.465321</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row6" class="row_heading level0 row6" >wd</th>
#       <td id="T_cb73f_row6_col0" class="data row6 col0" >903</td>
#       <td id="T_cb73f_row6_col1" class="data row6 col1" >0.515058</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row7" class="row_heading level0 row7" >DEWP</th>
#       <td id="T_cb73f_row7_col0" class="data row7 col0" >166</td>
#       <td id="T_cb73f_row7_col1" class="data row7 col1" >0.094684</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row8" class="row_heading level0 row8" >TEMP</th>
#       <td id="T_cb73f_row8_col0" class="data row8 col0" >163</td>
#       <td id="T_cb73f_row8_col1" class="data row8 col1" >0.092973</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row9" class="row_heading level0 row9" >RAIN</th>
#       <td id="T_cb73f_row9_col0" class="data row9 col0" >161</td>
#       <td id="T_cb73f_row9_col1" class="data row9 col1" >0.091832</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row10" class="row_heading level0 row10" >PRES</th>
#       <td id="T_cb73f_row10_col0" class="data row10 col0" >160</td>
#       <td id="T_cb73f_row10_col1" class="data row10 col1" >0.091262</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row11" class="row_heading level0 row11" >WSPM</th>
#       <td id="T_cb73f_row11_col0" class="data row11 col0" >128</td>
#       <td id="T_cb73f_row11_col1" class="data row11 col1" >0.073009</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row12" class="row_heading level0 row12" >year</th>
#       <td id="T_cb73f_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_cb73f_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row13" class="row_heading level0 row13" >No</th>
#       <td id="T_cb73f_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_cb73f_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row14" class="row_heading level0 row14" >day</th>
#       <td id="T_cb73f_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_cb73f_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row15" class="row_heading level0 row15" >month</th>
#       <td id="T_cb73f_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_cb73f_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row16" class="row_heading level0 row16" >hour</th>
#       <td id="T_cb73f_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_cb73f_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cb73f_level0_row17" class="row_heading level0 row17" >station</th>
#       <td id="T_cb73f_row17_col0" class="data row17 col0" >0</td>
#       <td id="T_cb73f_row17_col1" class="data row17 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.describe()
# Out:
#                   No          year          month            day  \
# count  175320.000000  175320.00000  175320.000000  175320.000000
# mean    17532.500000    2014.66256       6.522930      15.729637
# std     10122.133783       1.17720       3.448713       8.800117
# min         1.000000    2013.00000       1.000000       1.000000
# 25%      8766.750000    2014.00000       4.000000       8.000000
# 50%     17532.500000    2015.00000       7.000000      16.000000
# 75%     26298.250000    2016.00000      10.000000      23.000000
# max     35064.000000    2017.00000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  175320.000000  171873.000000  172751.000000  170932.000000
# mean       11.500000      79.222937     102.332299      15.053055
# std         6.922206      80.880112      90.558393      20.710885
# min         0.000000       2.000000       2.000000       0.285600
# 25%         5.750000      20.000000      35.000000       2.000000
# 50%        11.500000      54.000000      80.000000       7.000000
# 75%        17.250000     111.000000     142.000000      18.000000
# max        23.000000     999.000000     999.000000     411.000000
#
#                  NO2             CO             O3           TEMP  \
# count  170153.000000  166895.000000  168589.000000  175157.000000
# mean       49.138538    1217.253369      57.010496      13.591802
# std        35.251760    1163.808540      56.389886      11.408927
# min         1.026500     100.000000       0.214200     -16.800000
# 25%        21.000000     500.000000      10.000000       3.200000
# 50%        42.000000     900.000000      45.000000      14.600000
# 75%        70.000000    1500.000000      82.000000      23.300000
# max       264.000000   10000.000000     674.000000      41.400000
#
#                 PRES           DEWP           RAIN           WSPM
# count  175160.000000  175154.000000  175159.000000  175192.000000
# mean     1011.196055       2.478606       0.063614       1.753711
# std        10.485388      13.760064       0.800577       1.247106
# min       982.400000     -36.000000       0.000000       0.000000
# 25%      1002.700000      -8.900000       0.000000       0.900000
# 50%      1010.900000       3.100000       0.000000       1.400000
# 75%      1019.500000      15.100000       0.000000       2.200000
# max      1042.800000      28.800000      72.500000      13.200000

# %%
df['solid_pollutants'] = df['PM2.5'] + df['PM10']

# %%
df['gas_pollutants'] = df['SO2'] + df['NO2'] + df['CO'] + df['O3']

# %%
print(df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'solid_pollutants', 'gas_pollutants']].head())
# Out:
#    PM2.5  PM10  SO2  NO2     CO    O3  solid_pollutants  gas_pollutants
# 0    4.0   4.0  3.0  NaN  200.0  82.0               8.0             NaN
# 1    7.0   7.0  3.0  NaN  200.0  80.0              14.0             NaN
# 2    5.0   5.0  3.0  2.0  200.0  79.0              10.0           284.0
# 3    6.0   6.0  3.0  NaN  200.0  79.0              12.0             NaN
# 4    5.0   5.0  3.0  NaN  200.0  81.0              10.0             NaN
